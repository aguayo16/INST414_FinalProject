# %%
import requests
import json
import pandas as pd
auth = {"Authorization": "Token e3242fc4e9da547a8adda3abbcf328baa8e2ddd4"}
url = "https://app.climate.azavea.com/api/city"
resp = requests.get(url, headers=auth)
resp_obj=resp.content

# %%
data=json.loads(resp_obj)
cities=data['features']
#cities=pd.DataFrame(cities)
cities=pd.json_normalize(cities)
cities
# Out:
#       id     type geometry.type    geometry.coordinates  \
# 0    345  Feature         Point   [-76.16412, 39.50956]
# 1    521  Feature         Point   [-88.54366, 33.82511]
# 2    329  Feature         Point  [-123.81572, 46.97537]
# 3    692  Feature         Point   [-101.84295, 33.8323]
# 4   1240  Feature         Point   [-99.73314, 32.44874]
# 5    648  Feature         Point    [-90.4018, 40.80448]
# 6    438  Feature         Point   [-74.49571, 39.42845]
# 7    880  Feature         Point   [-89.17284, 33.31012]
# 8   1346  Feature         Point   [-71.43284, 42.48509]
# 9   1049  Feature         Point  [-116.24109, 43.45112]
# 10  1456  Feature         Point   [-96.82917, 32.96179]
# 11   344  Feature         Point   [-76.97192, 39.00317]
# 12   503  Feature         Point  [-117.59327, 47.64461]
# 13   121  Feature         Point   [-81.51901, 41.08144]
# 14  1587  Feature         Point    [-82.3577, 29.67476]
# 15  1010  Feature         Point  [-122.24164, 37.76521]
# 16  1026  Feature         Point  [-121.91789, 37.65055]
# 17  1622  Feature         Point  [-105.96027, 32.89953]
# 18  1133  Feature         Point  [-122.29775, 37.88687]
# 19  1303  Feature         Point   [-73.97356, 42.60018]
#
#     properties.proximity.ocean properties.name properties.admin  \
# 0                         True        Aberdeen               MD
# 1                        False        Aberdeen               MS
# 2                         True        Aberdeen               WA
# 3                        False       Abernathy               TX
# 4                        False         Abilene               TX
# 5                        False        Abingdon               IL
# 6                         True         Absecon               NJ
# 7                        False        Ackerman               MS
# 8                         True           Acton               MA
# 9                        False      Ada County               ID
# 10                       False         Addison               TX
# 11                        True         Adelphi               MD
# 12                       False  Airway Heights               WA
# 13                       False           Akron               OH
# 14                       False  Alachua County               FL
# 15                        True         Alameda               CA
# 16                       False  Alameda County               CA
# 17                       False      Alamogordo               NM
# 18                        True          Albany               CA
# 19                       False   Albany County               NY
#
#     properties.population properties.datasets  properties.region
# 0                   14959    [LOCA, NEX-GDDP]                 38
# 1                    5612    [LOCA, NEX-GDDP]                 38
# 2                   16896    [LOCA, NEX-GDDP]                 27
# 3                    2805    [LOCA, NEX-GDDP]                  8
# 4                  121721    [LOCA, NEX-GDDP]                  8
# 5                    3319    [LOCA, NEX-GDDP]                 38
# 6                    8411    [LOCA, NEX-GDDP]                 11
# 7                    1510    [LOCA, NEX-GDDP]                 38
# 8                   20897    [LOCA, NEX-GDDP]                 16
# 9                  392365    [LOCA, NEX-GDDP]                 33
# 10                  15518    [LOCA, NEX-GDDP]                  8
# 11                  15086    [LOCA, NEX-GDDP]                 38
# 12                   6114    [LOCA, NEX-GDDP]                 33
# 13                 199110    [LOCA, NEX-GDDP]                 16
# 14                 247336    [LOCA, NEX-GDDP]                 11
# 15                  78630    [LOCA, NEX-GDDP]                 18
# 16                1510271    [LOCA, NEX-GDDP]                 18
# 17                  30753    [LOCA, NEX-GDDP]                 51
# 18                  19735    [LOCA, NEX-GDDP]                 18
# 19                 304204    [LOCA, NEX-GDDP]                 16
